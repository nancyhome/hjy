# %%
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import transforms

# %%
img = Image.open("E:\Python\d2l-zh-1.0\hjy\lelush05.jpg")
print("原图大小：",img.size)
data1 = transforms.RandomResizedCrop(224)(img)
print("随机裁剪后的大小:",data1.size)
data2 = transforms.RandomResizedCrop(224)(img)
data3 = transforms.RandomResizedCrop(224)(img)
#画图找不到字体的话
#显示中文标签

plt.subplot(2,2,1),plt.imshow(img),plt.title("原图")
plt.subplot(2,2,2),plt.imshow(data1),plt.title("转换后的图1")
plt.subplot(2,2,3),plt.imshow(data2),plt.title("转换后的图2")
plt.subplot(2,2,4),plt.imshow(data3),plt.title("转换后的图3")
plt.show()
# Out:
# 原图大小： (1080, 1268)
# 随机裁剪后的大小: (224, 224)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21407 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 36716 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21518 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 30340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21407 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 36716 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25442 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21518 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\programdata\miniconda3\envs\pytorch\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 30340 missing from current font.
#   font.set_text(s, 0, flags=flags)
